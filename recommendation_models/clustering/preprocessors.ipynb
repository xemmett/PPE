# %%
# simple script to create multiple candidate datasets for clustering.
# the best data set will be chosen based on the elbow method for k-means clustering.
# Emmett Lawlor
# 28/09/2021

# %%
from pandas import read_csv, DataFrame

# %%
df = read_csv('../scrapers/qualifax_scraper/data/cleaned_search_results.csv', encoding='utf8', low_memory=False)

# %%
df.head(5)
# Out:
#               code                                               name  \
# 0            TU282                       Architecture - Bolton Street
# 1      TU231 TU232  Culinary Innovation & Food Product Development...
# 2            TU256                        Data Science - Grangegorman
# 3           106332                             Spirituality Awareness
# 4  DPCED-TCTL-1P09                   21st Century Teaching & Learning
#
#                                                 link    nfq_level  \
# 0  https://www.qualifax.ie/qf/QFPublic/?Mainsec=c...  Level 9 NFQ
# 1  https://www.qualifax.ie/qf/QFPublic/?Mainsec=c...  Level 9 NFQ
# 2  https://www.qualifax.ie/qf/QFPublic/?Mainsec=c...  Level 9 NFQ
# 3  https://www.qualifax.ie/qf/QFPublic/?Mainsec=c...          NaN
# 4  https://www.qualifax.ie/qf/QFPublic/?Mainsec=c...          NaN
#
#   nfq_classification                                     provider_1  \
# 0              Major  Technological University Dublin - City Campus
# ...

# %%
# we will break up some processing into parts and functions.

# %%
def prepareData(df: DataFrame(), columns: list):
    for c in columns:
        df[c] = dataset[c].astype('str').replace('nan', '').replace('\n', '')
        df[c] = df[c].str.lower()
        df['fulldesc'] += df[c]
    return df

# %%
def collegeBasedProcessing(df: DataFrame()):
    # create a unique set from college course description
    # iterate through set, if word is in every description, then remove it from the set.
    # iterate through each course description again, if word of course description is in set, write it
# Out:
#   File "C:\Users\Emmett\AppData\Local\Temp/ipykernel_29460/3440955292.py", line 2
#     # create a unique set from college cour se description
#                                                           ^
# IndentationError: expected an indented block

# %%
# remove grades from descriptions before this.
def descriptionBasedProcessing(df: DataFrame(), columns: list):
    # cross ref each course_desc against each course_desc, remove go line by line and remove duplicate sentences
    # levenshtein??

# %%
def courseBasedProcessing(df: DataFrame(), columns: list):
    # find similar courses across all colleges and process based on these.
